# %% [markdown]
# # Evaluation Runner Notebook
# Use this notebook to reproduce the Gemini-backed supervisor run exactly as it appears in our documentation.
#
# ## Prerequisites
# - Activate the project virtual environment (e.g., `source .venv/bin/activate`).
# - Ensure `.env` is populated with `GOOGLE_API_KEY` and any other required configuration.
# - Verify the repository root contains all installed dependencies (`pip install -r requirements.txt`).
#
# ## What the notebook does
# 1. Sets `PYTHONPATH` to include `src` so ADK imports resolve.
# 2. Loads key/value pairs from `.env` into the subprocess environment (without overwriting already-exported variables).
# 3. Invokes `scripts/run_adk_supervisor.py --verbose` with the standard prompt set to capture a full leadership briefing.
# 4. Prints STDOUT and STDERR so the transcript can be archived or inspected inline.
#
# Re-run the single code cell below after quotas reset to collect a fresh transcript for evaluation artifacts.

# %%
import os
import subprocess
from pathlib import Path

# %%
def find_repo_root(start: Path) -> Path:
    """Walk up from the starting directory until the project root is found."""
    for path in [start, *start.parents]:
        if (path / "README.md").exists() and (path / "src").exists():
            return path
    raise RuntimeError(f"Unable to locate repository root from {start}")

# %%
REPO_ROOT = find_repo_root(Path.cwd())
env = os.environ.copy()
env.setdefault("PYTHONPATH", str(REPO_ROOT / "src"))
env_path = REPO_ROOT / ".env"
if env_path.exists():
    for line in env_path.read_text().splitlines():
        if line.strip() and not line.startswith("#") and "=" in line:
            key, value = line.split("=", 1)
            env.setdefault(key.strip(), value.strip())

# %%
command = [
    "python",
    "scripts/run_adk_supervisor.py",
    "--verbose",
    "Give me an ops briefing: what happened overnight, what are the top risks, and what should leadership do next?",
    "Investigate prod-app-01 with the default window and summarize key log anomalies.",
    "Provide the utilization stats and risks.",
    "Draft the leadership summary and actions.",
]

# %%
result = subprocess.run(command, cwd=REPO_ROOT, env=env, capture_output=True, text=True)
print(result.stdout)
# Out:
#  ### Created new session: debug_session_id
#
# User > Give me an ops briefing: what happened overnight, what are the top risks, and what should leadership do next?
# it_ops_supervisor > [Calling tool: transfer_to_agent({'agent_name': 'log_analyst'})]
# it_ops_supervisor > [Tool result: {'result': None}]
# log_analyst > [Calling tool: fetch_server_logs({'window_minutes': 60})]
# log_analyst > [Tool result: {'result': '2025-11-29T04:50:31.133030Z [INFO] prod-app-01: Health check passed\n2025-11-29T04:55:31...]
# log_analyst > Overnight, the `prod-app-01` server experienced two critical database connection timeouts at 05:10 and 05:20. This was accompanied by a latency spike detected on the API Gateway at 05:30, and increasing replica lag. CPU utilization was also noted to be approaching a threshold.
#
# The top risks are:
# 1.  **Service Disruption:** The repeated database connection timeouts and API latency spikes indicate a potential for service degradation or outages.
# 2.  **Data Inconsistency:** Increasing replica lag can lead to data inconsistencies between primary and replica databases.
# 3.  **Performance Degradation:** High CPU utilization and API latency suggest the system is under strain and may impact user experience.
#
# **Recommendations for Leadership:**
# 1.  **Immediate Investigation:** Direct the operations team to conduct a thorough investigation into the root cause of the database connection timeouts and API latency spikes.
# 2.  **Performance Monitoring:** Allocate resources to closely monitor CPU utilization and replica lag. If these metrics continue to rise, proactive scaling or optimization measures should be considered.
# 3.  **Database Health Check:** Schedule a comprehensive health check of the database systems to ensure they are optimized and have sufficient resources.
#
# User > Investigate prod-app-01 with the default window and summarize key log anomalies.
# log_analyst > [Calling tool: fetch_server_logs({'server_id': 'prod-app-01'})]
# log_analyst > [Tool result: {'result': '2025-11-29T01:50:33.498842Z [WARN] prod-app-01: CPU utilization approaching threshold\n2...]
# log_analyst > The logs from `prod-app-01` show several anomalies over the default window:
#
# **Anomalies:**
# *   **CPU Utilization:** Warning logs indicate CPU utilization is repeatedly approaching thresholds at various times, including 01:50, 02:00, 02:45, 03:10, 03:25, and 04:55.
# *   **Replica Lag:** Warning logs show increasing replica lag at 01:55 and 05:15, with another warning at 05:35.
# *   **Cache Connection Retries:** Warning logs indicate retries connecting to the cache cluster at 02:15 and 02:25, with another warning at 04:35.
# *   **Disk Saturation:** Error logs report disk saturation beyond 95% at 03:15, 04:00, and 04:20.
# *   **Service Mesh Circuit Breaker:** Error logs indicate the service mesh circuit breaker is open at 04:05 and 04:25.
# *   **Database Connection Timeouts:** Critical errors show database connection timeouts at 05:10 and 05:20.
# *   **API Gateway Latency Spike:** An error log at 05:30 indicates a latency spike on the API Gateway.
#
# **Summary of Key Issues:**
# There are recurring issues with high CPU utilization, increasing replica lag, and problems connecting to the cache cluster. More critically, there are instances of disk saturation, open service mesh circuit breakers, database connection timeouts, and an API gateway latency spike. The pattern suggests a system under significant strain, possibly leading to performance degradation and potential service disruption.
#
# User > Provide the utilization stats and risks.
# log_analyst > [Calling tool: fetch_server_logs({'window_minutes': 240})]
# log_analyst > [Tool result: {'result': '2025-11-29T01:50:36.452533Z [WARN] prod-app-01: CPU utilization approaching threshold\n2...]
# log_analyst > The logs from `prod-app-01` over the last 240 minutes show the following utilization stats and associated risks:
#
# **Utilization Stats (based on log entries):**
#
# *   **CPU Utilization:** Repeatedly flagged as "approaching threshold" (WARNING level) at multiple intervals. This indicates sustained high CPU load.
# *   **Disk Saturation:** Critically high disk usage ("beyond 95%") occurred multiple times, marked as ERROR. This is a severe condition that can lead to system instability and data loss.
# *   **Replica Lag:** Observed to be "increasing" (WARNING level) at several points. This impacts data consistency and recovery capabilities.
# *   **Cache Connection Issues:** Repeated "retrying connection to cache cluster" (WARNING level) suggests problems with cache accessibility or performance.
# *   **API Gateway Latency:** A specific instance of a "latency spike" (ERROR level) was recorded, indicating performance issues affecting external access.
#
# **Identified Risks:**
#
# 1.  **System Instability and Downtime:** The combination of high CPU, disk saturation, and database connection timeouts points to a significant risk of system instability and potential outages. The open service mesh circuit breakers further exacerbate this risk by isolating services.
# 2.  **Data Loss or Corruption:** Disk saturation and increasing replica lag pose a risk to data integrity. If not addressed, this could lead to data loss or corruption.
# 3.  **Degraded Performance:** The frequent warnings about CPU utilization, cache connection issues, and the API gateway latency spike all indicate that the application's performance is degraded, which can negatively impact user experience and business operations.
# 4.  **Cascading Failures:** The interconnected nature of these issues (e.g., high CPU could lead to cache issues, which could impact database connections) means there's a risk of cascading failures where one problem triggers others.
#
# User > Draft the leadership summary and actions.
# log_analyst > Subject: Urgent: Overnight Incident Briefing - Prod-App-01 Performance Degradation
#
# **Executive Summary:**
#
# Overnight, `prod-app-01` experienced a series of critical performance issues, including multiple database connection timeouts, API gateway latency spikes, and severe disk saturation. These events indicate a significant degradation in service stability and performance, posing an immediate risk to operations.
#
# **Key Incidents & Observations:**
#
# *   **Database Connectivity:** Two critical database connection timeouts occurred at 05:10 and 05:20.
# *   **API Performance:** A significant latency spike was detected on the API Gateway at 05:30.
# *   **Resource Saturation:** Disk usage repeatedly exceeded 95% (ERROR level) at 03:15, 04:00, and 04:20.
# *   **System Strain:** CPU utilization was frequently noted as "approaching threshold" (WARNING level) throughout the observed period.
# *   **Data Replication Issues:** Increasing replica lag was observed at multiple intervals, raising concerns about data consistency.
# *   **Service Mesh Faults:** The service mesh circuit breaker was repeatedly opened (ERROR level), indicating potential communication failures between services.
# *   **Cache Connectivity:** The system experienced difficulties connecting to the cache cluster, requiring retries.
#
# **Top Risks:**
#
# 1.  **Service Outage:** The combination of database timeouts, API latency, and circuit breaker issues creates a high risk of a complete service outage.
# 2.  **Data Integrity Compromise:** Persistent disk saturation and replica lag could lead to data loss or corruption.
# 3.  **Prolonged Performance Degradation:** If the underlying causes are not addressed, users may experience continued slow response times and intermittent service access.
#
# **Recommended Actions:**
#
# 1.  **Immediate Root Cause Analysis:** The technical team must prioritize a deep-dive investigation to identify the root cause of the disk saturation, database timeouts, and API latency.
# 2.  **Resource Allocation Review:** Conduct an urgent review of resource allocation for `prod-app-01`, focusing on disk space, CPU, and memory to ensure adequate provisioning.
# 3.  **Monitoring Enhancement:** Implement enhanced monitoring and alerting for disk space, database connection pool health, and API latency to enable faster detection of future issues.
# 4.  **System Stability Testing:** Schedule immediate post-resolution stability testing to confirm the resilience of `prod-app-01` under load.
#
# We recommend immediate attention to these issues to mitigate further risks and restore optimal performance.

# %%
if result.stderr:
    print("--- STDERR ---")
    print(result.stderr)
# Out:
# --- STDERR ---
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/shiftmint/Documents/googleCapstone2/.venv/lib/python3.10/site-packages/google/adk/agents", which implies app name "agents".
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
